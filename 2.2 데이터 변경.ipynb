# %% [markdown]
# # 데이터 변경

# %%
#필요 라이브러리 로딩
import numpy as np
import pandas as pd

# %%
#지난 시간에 저장한 csv 로딩

df = pd.read_csv('./stuedent.csv')
display(df)
# Out:
#     이름   학과   성적
# 0  아이유  국문학  3.0
# 1  김연아   수학  1.0
# 2  홍길동  컴퓨터  3.5
# 3  장범준   철학  2.7
# 4  강감찬  경영학  4.0

# %%
import os

os.getcwd() #현재 디랙토리 위치
# Out:
# 'C:\\Users\\jaeha'

# %% [markdown]
# ### 컬럼 생성

# %%
# '등급' 컬럼 생성
df['등급'] = 'A' #새로운 컬럼 명시 후 값 부여
display(df)
# Out:
#     이름   학과   성적 등급
# 0  아이유  국문학  3.0  A
# 1  김연아   수학  1.0  A
# 2  홍길동  컴퓨터  3.5  A
# 3  장범준   철학  2.7  A
# 4  강감찬  경영학  4.0  A

# %%
# 성적에 따라 등급부여
grade = np.array(['B', 'D', 'B', 'C', 'A'])
df['등급'] = grade
display(df)
# Out:
#     이름   학과   성적 등급
# 0  아이유  국문학  3.0  B
# 1  김연아   수학  1.0  D
# 2  홍길동  컴퓨터  3.5  B
# 3  장범준   철학  2.7  C
# 4  강감찬  경영학  4.0  A

# %%
# 나이를 의미하는 age 라는 시리즈 생성

age = pd.Series([21, 20, 24, 23, 28])

df['나이'] = age
display(df)
# Out:
#     이름   학과   성적 등급  나이
# 0  아이유  국문학  3.0  B  21
# 1  김연아   수학  1.0  D  20
# 2  홍길동  컴퓨터  3.5  B  24
# 3  장범준   철학  2.7  C  23
# 4  강감찬  경영학  4.0  A  28

# %% [markdown]
# ### 인덱스 설정 및 리셋

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# 데이터 프레임의 인덱스는 df.index를 명시하여 접근할 수 있음
df.index = ["one", "two", "three", "four", "five"] # 인덱스의 값을 바꾸고 싶다면 인데스의 개수 만큼의 원소를 포함한 리스트를 할당하여 변경
df
# Out:
#         이름   학과   성적 등급  나이
# one    아이유  국문학  3.0  B  21
# two    김연아   수학  1.0  D  20
# three  홍길동  컴퓨터  3.5  B  24
# four   장범준   철학  2.7  C  23
# five   강감찬  경영학  4.0  A  28

# %%
# 새로운 컬럼 성별[sex] 생성
sex = pd.Series(['여자', '여자','남자', '남자', '님자'])
df['성별'] = sex
display(df)
# Out:
#         이름   학과   성적 등급  나이   성별
# one    아이유  국문학  3.0  B  21  NaN
# two    김연아   수학  1.0  D  20  NaN
# three  홍길동  컴퓨터  3.5  B  24  NaN
# four   장범준   철학  2.7  C  23  NaN
# five   강감찬  경영학  4.0  A  28  NaN

# %%
# sex 시리즈 인덱스 확인
sex.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# 시리즈 sex와 데이터프레임 df의 인덱스 출력
print('시리즈 sex의 인덱스 -->', sex.index)
print('데이터프레임 df의 인덱스 -->', df.index)
# Out:
# 시리즈 sex의 인덱스 --> RangeIndex(start=0, stop=5, step=1)
# 데이터프레임 df의 인덱스 --> Index(['one', 'two', 'three', 'four', 'five'], dtype='object')

# %%
#인덱스 통일 후 다시 성별 컬럼에 값 부여
sex.index = df.index
df['성별'] = sex
display(df)
# Out:
#         이름   학과   성적 등급  나이  성별
# one    아이유  국문학  3.0  B  21  여자
# two    김연아   수학  1.0  D  20  여자
# three  홍길동  컴퓨터  3.5  B  24  남자
# four   장범준   철학  2.7  C  23  남자
# five   강감찬  경영학  4.0  A  28  님자

# %%
#현재 설정되어 있는 인덱스 리셋
#df.reset_index(inplace=True) # inplace = True라는 인수값을 주면 원본에 바로 적용
df.reset_index()
# Out:
#    index   이름   학과   성적 등급  나이  성별
# 0    one  아이유  국문학  3.0  B  21  여자
# 1    two  김연아   수학  1.0  D  20  여자
# 2  three  홍길동  컴퓨터  3.5  B  24  남자
# 3   four  장범준   철학  2.7  C  23  남자
# 4   five  강감찬  경영학  4.0  A  28  님자

# %%
df
# Out:
#         이름   학과   성적 등급  나이  성별
# one    아이유  국문학  3.0  B  21  여자
# two    김연아   수학  1.0  D  20  여자
# three  홍길동  컴퓨터  3.5  B  24  남자
# four   장범준   철학  2.7  C  23  남자
# five   강감찬  경영학  4.0  A  28  님자

# %%
df.reset_index(inplace=True)
df
# Out:
#    index   이름   학과   성적 등급  나이  성별
# 0    one  아이유  국문학  3.0  B  21  여자
# 1    two  김연아   수학  1.0  D  20  여자
# 2  three  홍길동  컴퓨터  3.5  B  24  남자
# 3   four  장범준   철학  2.7  C  23  남자
# 4   five  강감찬  경영학  4.0  A  28  님자

# %%
#index 설정
#df.set_index('index', inplace=True) index 컬럼에 대하여 set_index
df.set_index('이름')
# Out:
#      index   학과   성적 등급  나이  성별
# 이름
# 아이유    one  국문학  3.0  B  21  여자
# 김연아    two   수학  1.0  D  20  여자
# 홍길동  three  컴퓨터  3.5  B  24  남자
# 장범준   four   철학  2.7  C  23  남자
# 강감찬   five  경영학  4.0  A  28  님자

# %%
#원본에 적용
df.set_index('index', inplace=True)

# %%
display(df)
# Out:
#         이름   학과   성적 등급  나이  성별
# index
# one    아이유  국문학  3.0  B  21  여자
# two    김연아   수학  1.0  D  20  여자
# three  홍길동  컴퓨터  3.5  B  24  남자
# four   장범준   철학  2.7  C  23  남자
# five   강감찬  경영학  4.0  A  28  님자

# %% [markdown]
# ### 컬럼 삭제

# %%
# 성별 컬럼 삭제 (dataframe의 drop 메서드 이용)
df.drop('성별', axis=1) #drop에서 axis=1의 값을 주면 컬럼을 삭제하겠다는 의미
# Out:
#         이름   학과   성적 등급  나이
# index
# one    아이유  국문학  3.0  B  21
# two    김연아   수학  1.0  D  20
# three  홍길동  컴퓨터  3.5  B  24
# four   장범준   철학  2.7  C  23
# five   강감찬  경영학  4.0  A  28

# %%
df
# Out:
#         이름   학과   성적 등급  나이  성별
# index
# one    아이유  국문학  3.0  B  21  여자
# two    김연아   수학  1.0  D  20  여자
# three  홍길동  컴퓨터  3.5  B  24  남자
# four   장범준   철학  2.7  C  23  남자
# five   강감찬  경영학  4.0  A  28  님자

# %%
df.drop('성별', axis='columns') #axis = 1 대신 axis='colsums' 라고 직접 명시해주어도 됨
# Out:
#         이름   학과   성적 등급  나이
# index
# one    아이유  국문학  3.0  B  21
# two    김연아   수학  1.0  D  20
# three  홍길동  컴퓨터  3.5  B  24
# four   장범준   철학  2.7  C  23
# five   강감찬  경영학  4.0  A  28

# %%
df #원본 dataframe에선 성별 컬럼이 삭제되지 안흥ㄴ걸을 확인
# Out:
#         이름   학과   성적 등급  나이  성별
# index
# one    아이유  국문학  3.0  B  21  여자
# two    김연아   수학  1.0  D  20  여자
# three  홍길동  컴퓨터  3.5  B  24  남자
# four   장범준   철학  2.7  C  23  남자
# five   강감찬  경영학  4.0  A  28  님자

# %%
#컬럼을 완전히 삭제 하는 방법

#방법1. 해당 피처를 제외한 새로운 데이터프레임 생성
df2 = df.drop('성별', axis=1)
df2
# Out:
#         이름   학과   성적 등급  나이
# index
# one    아이유  국문학  3.0  B  21
# two    김연아   수학  1.0  D  20
# three  홍길동  컴퓨터  3.5  B  24
# four   장범준   철학  2.7  C  23
# five   강감찬  경영학  4.0  A  28

# %%
# 원본 데이터 변경 확인
df
# Out:
#         이름   학과   성적 등급  나이  성별
# index
# one    아이유  국문학  3.0  B  21  여자
# two    김연아   수학  1.0  D  20  여자
# three  홍길동  컴퓨터  3.5  B  24  남자
# four   장범준   철학  2.7  C  23  남자
# five   강감찬  경영학  4.0  A  28  님자

# %%
#방법2. 원본데이터에서 해당 피처 삭제
df.drop('성별', axis=1, inplace=True) # inplace=True 인수 설정

# %%
df
# Out:
#         이름   학과   성적 등급  나이
# index
# one    아이유  국문학  3.0  B  21
# two    김연아   수학  1.0  D  20
# three  홍길동  컴퓨터  3.5  B  24
# four   장범준   철학  2.7  C  23
# five   강감찬  경영학  4.0  A  28

# %%
# 데이터 프레임 행 삭제
df.drop('one', axis=0) #one이라는 인덱스를 가진 행을 삭제
# Out:
#         이름   학과   성적 등급  나이
# index
# two    김연아   수학  1.0  D  20
# three  홍길동  컴퓨터  3.5  B  24
# four   장범준   철학  2.7  C  23
# five   강감찬  경영학  4.0  A  28

# %% [markdown]
# # 실습: 전국 무인 단속 카메라 표준데이터 json 데이터 pandas로 호출하기

# %%
#필요 라이브러리 로딩
import pandas as pd
import json #json을 다루기 위한 라이브러리
import requests #서버 쪽에 request 보낼 때 사용하는 라이브러리

# %%
# open api 호출시 필요한 정보 입력

key = 'RYTXXdeEW3GPhSUZ1Cs3uf4Dal3DY6eRbkPmlloN4aUwD4EMrAYNPBKjI1flxNpYeicFg9a53ZCIC%2F5sjbqTFQ%3D%3D'

pageNo = 0 # 요청 변수 : 페이지 번호 입력
row = 100 # 요청 변수 : 한페이지 결과 수 입력

# full url 입력 : '주소' + '?servicekey=키' + &pageNo=페이지번호'+'&numOfRows= 한 페이지 출력 괄과수' + '&type=json'
url = f'http://api.data.go.kr/openapi/tn_pubr_public_unmanned_traffic_camera_api?serviceKey={key}&pageNo={pageNo}&numOfRows={row}&type=json'

response = requests.get(url)

# 한글 출력 시 encoding이 필요함
response.encoding = 'utf-8' #utf-8으로 설정

print(response.text[0:600]) # response객체의 text 출력(출력되는 글자수를 지정함)
# Out:
# {"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE","type":"json"},"body":{"items":[{"mnlssRegltCameraManageNo":"23","ctprvnNm":"전라북도","signguNm":"익산시","roadKnd":"기타","roadRouteNo":"","roadRouteNm":"동서로","roadRouteDrc":"3","rdnmadr":"","lnmadr":"전라북도 익산시 남중동 375-193","latitude":"35.9533199","longitude":"126.9589814","itlpc":"남중동 북부시장사거리","regltSe":"4","lmttVe":"0","regltSctnLcSe":"","ovrspdRegltSctnLt":"","prtcareaType":"","installationYear":"2015","institutionNm":"전라북도 익산시청","phoneNumber":"063-859-5571","referenceDate":"2023-09-04","insttCode":"4680000"},{"mnlssRegltCameraMa

# %%
# 2. 결과 객체에 있는 데이터(json)조회
resulting_dict = json.loads(response.text) #json을 dict 타입으로 바꾸는 함수
#print(resulting_dict['header'])
resulting_dict.keys() # dictionary 키 확인 --> 중첩 딕셔너리임
# Out:
# dict_keys(['response'])

# %%
#중첩 딕셔너리 키확인
resulting_dict['response'].keys()
# Out:
# dict_keys(['header', 'body'])

# %%
resulting_dict['response']['body'].keys()
# Out:
# dict_keys(['items', 'totalCount', 'numOfRows', 'pageNo'])

# %%
resulting_dict['response']['body']['items']
# Out:
# [{'mnlssRegltCameraManageNo': '23',
#   'ctprvnNm': '전라북도',
#   'signguNm': '익산시',
#   'roadKnd': '기타',
#   'roadRouteNo': '',
#   'roadRouteNm': '동서로',
#   'roadRouteDrc': '3',
#   'rdnmadr': '',
#   'lnmadr': '전라북도 익산시 남중동 375-193',
#   'latitude': '35.9533199',
#   'longitude': '126.9589814',
#   'itlpc': '남중동 북부시장사거리',
#   'regltSe': '4',
#   'lmttVe': '0',
#   'regltSctnLcSe': '',
#   'ovrspdRegltSctnLt': '',
#   'prtcareaType': '',
#   'installationYear': '2015',
#   'institutionNm': '전라북도 익산시청',
#   'phoneNumber': '063-859-5571',
#   'referenceDate': '2023-09-04',
#   'insttCode': '4680000'},
#  {'mnlssRegltCameraManageNo': '24',
#   'ctprvnNm': '전라북도',
#   'signguNm': '익산시',
#   'roadKnd': '기타',
#   'roadRouteNo': '',
#   'roadRouteNm': '고봉로',
#   'roadRouteDrc': '3',
#   'rdnmadr': '',
#   'lnmadr': '전라북도 익산시 영등동 867',
#   'latitude': '35.9603375',
#   'longitude': '126.9712455',
#   'itlpc': '영등2동 아이스링크',
#   'regltSe': '4',
#   'lmttVe': '0',
#   'regltSctnLcSe': '',
# ...

# %%
#첫번째 아이템 호출
resulting_dict['response']['body']['items'][0]
# Out:
# {'mnlssRegltCameraManageNo': '23',
#  'ctprvnNm': '전라북도',
#  'signguNm': '익산시',
#  'roadKnd': '기타',
#  'roadRouteNo': '',
#  'roadRouteNm': '동서로',
#  'roadRouteDrc': '3',
#  'rdnmadr': '',
#  'lnmadr': '전라북도 익산시 남중동 375-193',
#  'latitude': '35.9533199',
#  'longitude': '126.9589814',
#  'itlpc': '남중동 북부시장사거리',
#  'regltSe': '4',
#  'lmttVe': '0',
#  'regltSctnLcSe': '',
#  'ovrspdRegltSctnLt': '',
#  'prtcareaType': '',
#  'installationYear': '2015',
#  'institutionNm': '전라북도 익산시청',
#  'phoneNumber': '063-859-5571',
#  'referenceDate': '2023-09-04',
#  'insttCode': '4680000'}

# %%
# 주소, 카메라 위치, 위도, 경도의 정보만 출력
address_list= []
location_list = []
latitude_list= []
longitude_list =[]

#dictionary 속 데이터 정보 입력

for tmp in resulting_dict['response']['body']['items']:
    address_list.append(tmp['lnmadr'])
    location_list.append(tmp['itlpc'])
    latitude_list.append(tmp['latitude'])
    longitude_list.append(tmp['longitude'])

# %%
print(address_list[:10])
print(location_list[:10])
print(longitude_list[:10])
# Out:
# ['전라북도 익산시 남중동 375-193', '전라북도 익산시 영등동 867', '전라북도 익산시 어양동 663', '전라북도 익산시 모현동1가 915', '전라북도 익산시 영등동 543-56', '전라북도 익산시 남중동 375-193', '전라북도 익산시 중앙동1가 87', '전라북도 익산시 동산동 685', '전라북도 익산시 영등동 869', '인천광역시 동구 화평동 1-48']
# ['남중동 북부시장사거리', '영등2동 아이스링크', '영등1동 전자랜드사거리', '모현동 부영1차아파트', '영등1동 동부시장', '남중동 북부시장', '중앙동 중앙시장길 앞', '동산동 E마트', '영등2동 롯데마트', '송화로 송현초교 앞']
# ['126.9589814', '126.9712455', '126.9812617', '126.9378014', '126.9641853', '126.9589814', '126.9489387', '126.9575522', '126.9748498', '126.6328919']

# %%
#dataFrame으로 변환

df = pd.DataFrame({
    'address' : address_list,
    'location' : location_list,
    'latitude' : latitude_list,
    'longitude' : longitude_list
})

display(df)
# Out:
#                  address                         location     latitude  \
# 0   전라북도 익산시 남중동 375-193                      남중동 북부시장사거리   35.9533199
# 1       전라북도 익산시 영등동 867                       영등2동 아이스링크   35.9603375
# 2       전라북도 익산시 어양동 663                     영등1동 전자랜드사거리   35.9620134
# 3     전라북도 익산시 모현동1가 915                      모현동 부영1차아파트   35.9508394
# 4    전라북도 익산시 영등동 543-56                        영등1동 동부시장   35.9472724
# ..                   ...                              ...          ...
# 95  경기도 고양시 일산서구 주엽동 101                   주엽동 101 강선14단지  37.66848587
# 96   경기도 고양시 일산서구 주엽동 75                  주엽동 75 일산아카데미 앞  37.66781012
# 97   경기도 고양시 일산서구 주엽동 73                   주엽동 73 태영프라자 앞  37.66834954
# 98   경기도 고양시 일산서구 주엽동 65                   주엽동 65 주엽지구대 앞  37.67037914
# 99   경기도 고양시 일산서구 주엽동 86  주엽동 86 (강선16단지 앞/강선마을13단지출입구일원)  37.66634901
#
#       longitude
# 0   126.9589814
# 1   126.9712455
# 2   126.9812617
# 3   126.9378014
# 4   126.9641853
# ...
